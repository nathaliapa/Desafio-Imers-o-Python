# %% [markdown]
# **Aula 2 importação**

# %% [markdown]
# *   importar a bibliote panda e definir uma nomeclatura.
# *   plotly.express para grafico

# %%
import pandas as pd
import plotly.express as px

# %% [markdown]
# definir uma variavel.
#
# .read_"tipo de executavel"(caminho do arquivo, nome da pagina )
#
# variavel+ação da variavel.
#
# .head() = pega o intevaldo de linhas que deve ser monstrado sem ele mostra a tabela de forma resumida.

# %%
df_principal = pd.read_excel('/content/Aula 2 de Imersão Python - Tabela de ações.xlsx',sheet_name='Principal')
df_principal.head(10)
# Out:
#    Ativo       Data  Último (R$)  Var. Dia (%)  Var. Sem. (%)  Var. Mês (%)  \
# 0  USIM5 2024-01-26         9.50          5.20          11.76          2.26
# 1  CMIN3 2024-01-26         6.82          2.40           2.40        -12.11
# 2  PETR3 2024-01-26        41.96          2.19           7.73          7.64
# 3  SUZB3 2024-01-26        52.91          2.04           2.14         -4.89
# 4  CPFE3 2024-01-26        37.10          2.03           2.49         -3.66
# 5  PRIO3 2024-01-26        45.69          1.98           2.42         -0.78
# 6  PETR4 2024-01-26        39.96          1.73           6.47          7.30
# 7  VALE3 2024-01-26        69.50          1.66           2.06         -9.97
# 8  MULT3 2024-01-26        28.19          1.58           2.03         -0.81
# 9  ITUB4 2024-01-26        32.81          1.48          -0.39         -3.36
#
#    Var. Ano (%)  Var. 12M (%)  Val. Mín  Val. Máx    Volume  Variação %  \
# 0          2.26         15.97      9.18      9.56  319,16 M      0.0520
# 1        -12.11         50.56      6.66      6.86   32,65 M      0.0240
# 2          7.64         77.55     40.81     42.34  436,69 M      0.0219
# 3         -4.89         18.85     51.89     53.17  162,55 M      0.0204
# 4         -3.66         20.70     36.37     37.32   73,42 M      0.0203
# 5         -0.78          8.08     44.25     45.69  319,92 M      0.0198
# 6          7.30         95.01     38.91     40.09    1,64 B      0.0173
# 7         -9.97        -23.49     67.50     69.81    1,89 B      0.0166
# 8         -0.81         24.02     27.71     28.36  104,16 M      0.0158
# 9         -3.36         34.25     32.35     32.91   473,2 M      0.0148
#
#    Valor Inicial (R$)  Quantidade de acoes  Variação  (R$) Resultado  \
# 0            9.030418            515117391    2.418897e+08     Subiu
# 1            6.660156           1110559345    1.775160e+08     Subiu
# 2           41.060769           2379877655    2.140059e+09     Subiu
# 3           51.852215            683452836    7.229463e+08     Subiu
# 4           36.361854            187732538    1.385740e+08     Subiu
# 5           44.802903            800010734    7.096875e+08     Subiu
# 6           39.280448           4566445852    3.103136e+09     Subiu
# 7           68.365139           4196924316    4.762927e+09     Subiu
# 8           27.751526            268505432    1.177327e+08     Subiu
# 9           32.331494           4801593832    2.297592e+09     Subiu
#
#             Nome              Segmento  Idade          Cat_Idade
# 0       Usiminas            Siderurgia     60  Entre de 50 e 100
# 1  CSN Mineração             Mineração     80  Entre de 50 e 100
# 2      Petrobras        Petróleo e Gás     69  Entre de 50 e 100
# 3         Suzano      Papel e Celulose     94  Entre de 50 e 100
# 4   CPFL Energia               Energia    108   Mais de 100 anos
# 5       PetroRio        Petróleo e Gás     11        Menos de 50
# 6      Petrobras        Petróleo e Gás     69  Entre de 50 e 100
# 7           Vale             Mineração     80  Entre de 50 e 100
# 8      Multiplan      Shopping Centers     50  Entre de 50 e 100
# 9  Itaú Unibanco  Serviços Financeiros     17        Menos de 50

# %%
df_Total_de_acoes = pd.read_excel('/content/Aula 2 de Imersão Python - Tabela de ações.xlsx',sheet_name='Total_de_acoes')
df_Total_de_acoes.head(10)
# Out:
#   Código  Qtde. Teórica
# 0  RRRP3   2.356656e+08
# 1  ALOS3   5.326166e+08
# 2  ALPA4   1.767340e+08
# 3  ABEV3   4.394246e+09
# 4  ARZZ3   6.230589e+07
# 5  ASAI3   1.349218e+09
# 6  AZUL4   3.275937e+08
# 7  B3SA3   5.602790e+09
# 8  BBSE3   6.717508e+08
# 9  BBDC3   1.500729e+09

# %%
df_Ticker = pd.read_excel('/content/Aula 2 de Imersão Python - Tabela de ações.xlsx',sheet_name='Ticker')
df_Ticker.head(10)
# Out:
#   Ticker            Nome
# 0  MGLU3  Magazine Luiza
# 1  HAPV3         Hapvida
# 2  PETR4       Petrobras
# 3  B3SA3              B3
# 4  USIM5        Usiminas
# 5  CVCB3             CVC
# 6  CIEL3           Cielo
# 7  VALE3            Vale
# 8  GOLL4             GOL
# 9  BBDC4  Banco Bradesco

# %%
df_Chat_GPT = pd.read_excel('/content/Aula 2 de Imersão Python - Tabela de ações.xlsx',sheet_name='Chat_GPT')
df_Chat_GPT.head(10)
# Out:
#          Empresa              Segmento  Idade (anos)
# 0       Usiminas            Siderurgia            60
# 1  CSN Mineração             Mineração            80
# 2      Petrobras        Petróleo e Gás            69
# 3         Suzano      Papel e Celulose            94
# 4   CPFL Energia               Energia           108
# 5       PetroRio        Petróleo e Gás            11
# 6      Petrobras        Petróleo e Gás            69
# 7           Vale             Mineração            80
# 8      Multiplan      Shopping Centers            50
# 9  Itaú Unibanco  Serviços Financeiros            17

# %% [markdown]
# manupulação de dataframe

# %%
df_principal = df_principal[['Ativo','Data','Último (R$)','Var. Dia (%)']].copy()
df_principal
# Out:
#     Ativo       Data  Último (R$)  Var. Dia (%)
# 0   USIM5 2024-01-26         9.50          5.20
# 1   CMIN3 2024-01-26         6.82          2.40
# 2   PETR3 2024-01-26        41.96          2.19
# 3   SUZB3 2024-01-26        52.91          2.04
# 4   CPFE3 2024-01-26        37.10          2.03
# ..    ...        ...          ...           ...
# 76  CRFB3 2024-01-26        10.71         -2.45
# 77  BHIA3 2024-01-26         8.70         -2.46
# 78  RENT3 2024-01-26        56.24         -3.63
# 79  CVCB3 2024-01-26         3.07         -4.36
# 80  GOLL4 2024-01-26         5.92         -8.07
#
# [81 rows x 4 columns]

# %%
df_principal = df_principal.rename(columns={'Último (R$)':'Valor_Final','Var. Dia (%)':'Var_Dia_PCT'}).copy()
df_principal
# Out:
#     Ativo       Data  Valor_Final  Var_Dia_PCT
# 0   USIM5 2024-01-26         9.50         5.20
# 1   CMIN3 2024-01-26         6.82         2.40
# 2   PETR3 2024-01-26        41.96         2.19
# 3   SUZB3 2024-01-26        52.91         2.04
# 4   CPFE3 2024-01-26        37.10         2.03
# ..    ...        ...          ...          ...
# 76  CRFB3 2024-01-26        10.71        -2.45
# 77  BHIA3 2024-01-26         8.70        -2.46
# 78  RENT3 2024-01-26        56.24        -3.63
# 79  CVCB3 2024-01-26         3.07        -4.36
# 80  GOLL4 2024-01-26         5.92        -8.07
#
# [81 rows x 4 columns]

# %%
df_principal['Var_pct'] = df_principal['Var_Dia_PCT'] / 100
df_principal['Var_Inicial'] = df_principal['Valor_Final'] / (df_principal['Var_pct'] + 1)
df_principal
# Out:
#     Ativo       Data  Valor_Final  Var_Dia_PCT  Var_pct  Var_Inicial
# 0   USIM5 2024-01-26         9.50         5.20   0.0520     9.030418
# 1   CMIN3 2024-01-26         6.82         2.40   0.0240     6.660156
# 2   PETR3 2024-01-26        41.96         2.19   0.0219    41.060769
# 3   SUZB3 2024-01-26        52.91         2.04   0.0204    51.852215
# 4   CPFE3 2024-01-26        37.10         2.03   0.0203    36.361854
# ..    ...        ...          ...          ...      ...          ...
# 76  CRFB3 2024-01-26        10.71        -2.45  -0.0245    10.978985
# 77  BHIA3 2024-01-26         8.70        -2.46  -0.0246     8.919418
# 78  RENT3 2024-01-26        56.24        -3.63  -0.0363    58.358410
# 79  CVCB3 2024-01-26         3.07        -4.36  -0.0436     3.209954
# 80  GOLL4 2024-01-26         5.92        -8.07  -0.0807     6.439682
#
# [81 rows x 6 columns]

# %%
df_principal = df_principal.merge(df_Total_de_acoes,left_on='Ativo', right_on='Código', how='left' )
df_principal
# Out:
#     Ativo       Data  Valor_Final  Var_Dia_PCT  Var_pct  Var_Inicial Código  \
# 0   USIM5 2024-01-26         9.50         5.20   0.0520     9.030418  USIM5
# 1   CMIN3 2024-01-26         6.82         2.40   0.0240     6.660156  CMIN3
# 2   PETR3 2024-01-26        41.96         2.19   0.0219    41.060769  PETR3
# 3   SUZB3 2024-01-26        52.91         2.04   0.0204    51.852215  SUZB3
# 4   CPFE3 2024-01-26        37.10         2.03   0.0203    36.361854  CPFE3
# ..    ...        ...          ...          ...      ...          ...    ...
# 76  CRFB3 2024-01-26        10.71        -2.45  -0.0245    10.978985  CRFB3
# 77  BHIA3 2024-01-26         8.70        -2.46  -0.0246     8.919418  BHIA3
# 78  RENT3 2024-01-26        56.24        -3.63  -0.0363    58.358410  RENT3
# 79  CVCB3 2024-01-26         3.07        -4.36  -0.0436     3.209954  CVCB3
# 80  GOLL4 2024-01-26         5.92        -8.07  -0.0807     6.439682  GOLL4
#
#     Qtde. Teórica
# 0    5.151174e+08
# 1    1.110559e+09
# 2    2.379878e+09
# 3    6.834528e+08
# 4    1.877325e+08
# ..            ...
# 76   5.339906e+08
# 77   9.484305e+07
# 78   8.532023e+08
# 79   5.255828e+08
# 80   1.981849e+08
#
# [81 rows x 8 columns]

# %%
df_principal = df_principal.drop(columns=['Código'])
df_principal
# Out:
#     Ativo       Data  Valor_Final  Var_Dia_PCT  Var_pct  Var_Inicial  \
# 0   USIM5 2024-01-26         9.50         5.20   0.0520     9.030418
# 1   CMIN3 2024-01-26         6.82         2.40   0.0240     6.660156
# 2   PETR3 2024-01-26        41.96         2.19   0.0219    41.060769
# 3   SUZB3 2024-01-26        52.91         2.04   0.0204    51.852215
# 4   CPFE3 2024-01-26        37.10         2.03   0.0203    36.361854
# ..    ...        ...          ...          ...      ...          ...
# 76  CRFB3 2024-01-26        10.71        -2.45  -0.0245    10.978985
# 77  BHIA3 2024-01-26         8.70        -2.46  -0.0246     8.919418
# 78  RENT3 2024-01-26        56.24        -3.63  -0.0363    58.358410
# 79  CVCB3 2024-01-26         3.07        -4.36  -0.0436     3.209954
# 80  GOLL4 2024-01-26         5.92        -8.07  -0.0807     6.439682
#
#     Qtde. Teórica
# 0    5.151174e+08
# 1    1.110559e+09
# 2    2.379878e+09
# 3    6.834528e+08
# 4    1.877325e+08
# ..            ...
# 76   5.339906e+08
# 77   9.484305e+07
# 78   8.532023e+08
# 79   5.255828e+08
# 80   1.981849e+08
#
# [81 rows x 7 columns]

# %%
df_principal['Variacao_RS'] = (df_principal['Valor_Final'] - df_principal['Var_Inicial']) * df_principal['Qtde. Teórica']
df_principal
# Out:
#     Ativo       Data  Valor_Final  Var_Dia_PCT  Var_pct  Var_Inicial  \
# 0   USIM5 2024-01-26         9.50         5.20   0.0520     9.030418
# 1   CMIN3 2024-01-26         6.82         2.40   0.0240     6.660156
# 2   PETR3 2024-01-26        41.96         2.19   0.0219    41.060769
# 3   SUZB3 2024-01-26        52.91         2.04   0.0204    51.852215
# 4   CPFE3 2024-01-26        37.10         2.03   0.0203    36.361854
# ..    ...        ...          ...          ...      ...          ...
# 76  CRFB3 2024-01-26        10.71        -2.45  -0.0245    10.978985
# 77  BHIA3 2024-01-26         8.70        -2.46  -0.0246     8.919418
# 78  RENT3 2024-01-26        56.24        -3.63  -0.0363    58.358410
# 79  CVCB3 2024-01-26         3.07        -4.36  -0.0436     3.209954
# 80  GOLL4 2024-01-26         5.92        -8.07  -0.0807     6.439682
#
#     Qtde. Teórica   Variacao_RS
# 0    5.151174e+08  2.418897e+08
# 1    1.110559e+09  1.775160e+08
# 2    2.379878e+09  2.140059e+09
# 3    6.834528e+08  7.229463e+08
# 4    1.877325e+08  1.385740e+08
# ..            ...           ...
# 76   5.339906e+08 -1.436355e+08
# 77   9.484305e+07 -2.081024e+07
# 78   8.532023e+08 -1.807433e+09
# 79   5.255828e+08 -7.355741e+07
# 80   1.981849e+08 -1.029932e+08
#
# [81 rows x 8 columns]

# %%
pd.options.display.float_format= '{:.2f}'.format

# %%
df_principal['Qtde. Teórica'] = df_principal['Qtde. Teórica'].astype(int)
df_principal
# Out:
#     Ativo       Data  Valor_Final  Var_Dia_PCT  Var_pct  Var_Inicial  \
# 0   USIM5 2024-01-26         9.50         5.20     0.05         9.03
# 1   CMIN3 2024-01-26         6.82         2.40     0.02         6.66
# 2   PETR3 2024-01-26        41.96         2.19     0.02        41.06
# 3   SUZB3 2024-01-26        52.91         2.04     0.02        51.85
# 4   CPFE3 2024-01-26        37.10         2.03     0.02        36.36
# ..    ...        ...          ...          ...      ...          ...
# 76  CRFB3 2024-01-26        10.71        -2.45    -0.02        10.98
# 77  BHIA3 2024-01-26         8.70        -2.46    -0.02         8.92
# 78  RENT3 2024-01-26        56.24        -3.63    -0.04        58.36
# 79  CVCB3 2024-01-26         3.07        -4.36    -0.04         3.21
# 80  GOLL4 2024-01-26         5.92        -8.07    -0.08         6.44
#
#     Qtde. Teórica    Variacao_RS
# 0       515117391   241889725.43
# 1      1110559345   177515970.30
# 2      2379877655  2140059393.53
# 3       683452836   722946282.71
# 4       187732538   138573955.06
# ..            ...            ...
# 76      533990587  -143635530.57
# 77       94843047   -20810240.84
# 78      853202347 -1807432634.46
# 79      525582771   -73557408.06
# 80      198184909  -102993202.62
#
# [81 rows x 8 columns]

# %%
df_principal = df_principal.rename(columns={'Qtde. Teórica':'Qtde_teorica'}).copy()
df_principal
# Out:
#     Ativo       Data  Valor_Final  Var_Dia_PCT  Var_pct  Var_Inicial  \
# 0   USIM5 2024-01-26         9.50         5.20     0.05         9.03
# 1   CMIN3 2024-01-26         6.82         2.40     0.02         6.66
# 2   PETR3 2024-01-26        41.96         2.19     0.02        41.06
# 3   SUZB3 2024-01-26        52.91         2.04     0.02        51.85
# 4   CPFE3 2024-01-26        37.10         2.03     0.02        36.36
# ..    ...        ...          ...          ...      ...          ...
# 76  CRFB3 2024-01-26        10.71        -2.45    -0.02        10.98
# 77  BHIA3 2024-01-26         8.70        -2.46    -0.02         8.92
# 78  RENT3 2024-01-26        56.24        -3.63    -0.04        58.36
# 79  CVCB3 2024-01-26         3.07        -4.36    -0.04         3.21
# 80  GOLL4 2024-01-26         5.92        -8.07    -0.08         6.44
#
#     Qtde_teorica    Variacao_RS
# 0      515117391   241889725.43
# 1     1110559345   177515970.30
# 2     2379877655  2140059393.53
# 3      683452836   722946282.71
# 4      187732538   138573955.06
# ..           ...            ...
# 76     533990587  -143635530.57
# 77      94843047   -20810240.84
# 78     853202347 -1807432634.46
# 79     525582771   -73557408.06
# 80     198184909  -102993202.62
#
# [81 rows x 8 columns]

# %%
df_principal["Resultado"] = df_principal['Variacao_RS'].apply(lambda x: "Subiu" if x > 0 else ("Desceu" if x < 0 else "Estavel"))
df_principal
# Out:
#     Ativo       Data  Valor_Final  Var_Dia_PCT  Var_pct  Var_Inicial  \
# 0   USIM5 2024-01-26         9.50         5.20     0.05         9.03
# 1   CMIN3 2024-01-26         6.82         2.40     0.02         6.66
# 2   PETR3 2024-01-26        41.96         2.19     0.02        41.06
# 3   SUZB3 2024-01-26        52.91         2.04     0.02        51.85
# 4   CPFE3 2024-01-26        37.10         2.03     0.02        36.36
# ..    ...        ...          ...          ...      ...          ...
# 76  CRFB3 2024-01-26        10.71        -2.45    -0.02        10.98
# 77  BHIA3 2024-01-26         8.70        -2.46    -0.02         8.92
# 78  RENT3 2024-01-26        56.24        -3.63    -0.04        58.36
# 79  CVCB3 2024-01-26         3.07        -4.36    -0.04         3.21
# 80  GOLL4 2024-01-26         5.92        -8.07    -0.08         6.44
#
#     Qtde_teorica    Variacao_RS Resultado
# 0      515117391   241889725.43     Subiu
# 1     1110559345   177515970.30     Subiu
# 2     2379877655  2140059393.53     Subiu
# 3      683452836   722946282.71     Subiu
# 4      187732538   138573955.06     Subiu
# ..           ...            ...       ...
# 76     533990587  -143635530.57    Desceu
# 77      94843047   -20810240.84    Desceu
# 78     853202347 -1807432634.46    Desceu
# 79     525582771   -73557408.06    Desceu
# 80     198184909  -102993202.62    Desceu
#
# [81 rows x 9 columns]

# %%
df_principal = df_principal.merge(df_Ticker, left_on='Ativo', right_on='Ticker', how='left')
df_principal = df_principal.drop(columns=['Ticker'])
df_principal
# Out:
#     Ativo       Data  Valor_Final  Var_Dia_PCT  Var_pct  Var_Inicial  \
# 0   USIM5 2024-01-26         9.50         5.20     0.05         9.03
# 1   CMIN3 2024-01-26         6.82         2.40     0.02         6.66
# 2   PETR3 2024-01-26        41.96         2.19     0.02        41.06
# 3   SUZB3 2024-01-26        52.91         2.04     0.02        51.85
# 4   CPFE3 2024-01-26        37.10         2.03     0.02        36.36
# ..    ...        ...          ...          ...      ...          ...
# 76  CRFB3 2024-01-26        10.71        -2.45    -0.02        10.98
# 77  BHIA3 2024-01-26         8.70        -2.46    -0.02         8.92
# 78  RENT3 2024-01-26        56.24        -3.63    -0.04        58.36
# 79  CVCB3 2024-01-26         3.07        -4.36    -0.04         3.21
# 80  GOLL4 2024-01-26         5.92        -8.07    -0.08         6.44
#
#     Qtde_teorica    Variacao_RS Resultado              Nome
# 0      515117391   241889725.43     Subiu          Usiminas
# 1     1110559345   177515970.30     Subiu     CSN Mineração
# 2     2379877655  2140059393.53     Subiu         Petrobras
# 3      683452836   722946282.71     Subiu            Suzano
# 4      187732538   138573955.06     Subiu      CPFL Energia
# ..           ...            ...       ...               ...
# 76     533990587  -143635530.57    Desceu  Carrefour Brasil
# 77      94843047   -20810240.84    Desceu       Casas Bahia
# 78     853202347 -1807432634.46    Desceu          Localiza
# 79     525582771   -73557408.06    Desceu               CVC
# 80     198184909  -102993202.62    Desceu               GOL
#
# [81 rows x 10 columns]

# %%
df_principal = df_principal.merge(df_Chat_GPT, left_on='Nome', right_on='Empresa', how='left')
df_principal = df_principal.drop(columns=['Empresa'])
df_principal
# Out:
#     Ativo       Data  Valor_Final  Var_Dia_PCT  Var_pct  Var_Inicial  \
# 0   USIM5 2024-01-26         9.50         5.20     0.05         9.03
# 1   CMIN3 2024-01-26         6.82         2.40     0.02         6.66
# 2   PETR3 2024-01-26        41.96         2.19     0.02        41.06
# 3   PETR3 2024-01-26        41.96         2.19     0.02        41.06
# 4   SUZB3 2024-01-26        52.91         2.04     0.02        51.85
# ..    ...        ...          ...          ...      ...          ...
# 78  CRFB3 2024-01-26        10.71        -2.45    -0.02        10.98
# 79  BHIA3 2024-01-26         8.70        -2.46    -0.02         8.92
# 80  RENT3 2024-01-26        56.24        -3.63    -0.04        58.36
# 81  CVCB3 2024-01-26         3.07        -4.36    -0.04         3.21
# 82  GOLL4 2024-01-26         5.92        -8.07    -0.08         6.44
#
#     Qtde_teorica    Variacao_RS Resultado              Nome  \
# 0      515117391   241889725.43     Subiu          Usiminas
# 1     1110559345   177515970.30     Subiu     CSN Mineração
# 2     2379877655  2140059393.53     Subiu         Petrobras
# 3     2379877655  2140059393.53     Subiu         Petrobras
# 4      683452836   722946282.71     Subiu            Suzano
# ..           ...            ...       ...               ...
# 78     533990587  -143635530.57    Desceu  Carrefour Brasil
# 79      94843047   -20810240.84    Desceu       Casas Bahia
# 80     853202347 -1807432634.46    Desceu          Localiza
# 81     525582771   -73557408.06    Desceu               CVC
# 82     198184909  -102993202.62    Desceu               GOL
#
#              Segmento  Idade (anos)
# 0          Siderurgia            60
# 1           Mineração            80
# 2      Petróleo e Gás            69
# 3      Petróleo e Gás            69
# 4    Papel e Celulose            94
# ..                ...           ...
# 78             Varejo            66
# 79             Varejo            68
# 80  Aluguel de Carros            48
# 81            Turismo            50
# 82   Transporte Aéreo            20
#
# [83 rows x 12 columns]

# %%
df_principal = df_principal.rename(columns={'Idade (anos)':'Idade'}).copy()
df_principal
# Out:
#     Ativo       Data  Valor_Final  Var_Dia_PCT  Var_pct  Var_Inicial  \
# 0   USIM5 2024-01-26         9.50         5.20     0.05         9.03
# 1   CMIN3 2024-01-26         6.82         2.40     0.02         6.66
# 2   PETR3 2024-01-26        41.96         2.19     0.02        41.06
# 3   PETR3 2024-01-26        41.96         2.19     0.02        41.06
# 4   SUZB3 2024-01-26        52.91         2.04     0.02        51.85
# ..    ...        ...          ...          ...      ...          ...
# 78  CRFB3 2024-01-26        10.71        -2.45    -0.02        10.98
# 79  BHIA3 2024-01-26         8.70        -2.46    -0.02         8.92
# 80  RENT3 2024-01-26        56.24        -3.63    -0.04        58.36
# 81  CVCB3 2024-01-26         3.07        -4.36    -0.04         3.21
# 82  GOLL4 2024-01-26         5.92        -8.07    -0.08         6.44
#
#     Qtde_teorica    Variacao_RS Resultado              Nome  \
# 0      515117391   241889725.43     Subiu          Usiminas
# 1     1110559345   177515970.30     Subiu     CSN Mineração
# 2     2379877655  2140059393.53     Subiu         Petrobras
# 3     2379877655  2140059393.53     Subiu         Petrobras
# 4      683452836   722946282.71     Subiu            Suzano
# ..           ...            ...       ...               ...
# 78     533990587  -143635530.57    Desceu  Carrefour Brasil
# 79      94843047   -20810240.84    Desceu       Casas Bahia
# 80     853202347 -1807432634.46    Desceu          Localiza
# 81     525582771   -73557408.06    Desceu               CVC
# 82     198184909  -102993202.62    Desceu               GOL
#
#              Segmento  Idade
# 0          Siderurgia     60
# 1           Mineração     80
# 2      Petróleo e Gás     69
# 3      Petróleo e Gás     69
# 4    Papel e Celulose     94
# ..                ...    ...
# 78             Varejo     66
# 79             Varejo     68
# 80  Aluguel de Carros     48
# 81            Turismo     50
# 82   Transporte Aéreo     20
#
# [83 rows x 12 columns]

# %%
df_principal["Cat_Idade"] = df_principal["Idade"].apply(lambda x: "Mais de 100 anos" if x > 100 else ("Menos de 50" if x < 50 else "Entre de 50 e 100"))
df_principal
# Out:
#     Ativo       Data  Valor_Final  Var_Dia_PCT  Var_pct  Var_Inicial  \
# 0   USIM5 2024-01-26         9.50         5.20     0.05         9.03
# 1   CMIN3 2024-01-26         6.82         2.40     0.02         6.66
# 2   PETR3 2024-01-26        41.96         2.19     0.02        41.06
# 3   PETR3 2024-01-26        41.96         2.19     0.02        41.06
# 4   SUZB3 2024-01-26        52.91         2.04     0.02        51.85
# ..    ...        ...          ...          ...      ...          ...
# 78  CRFB3 2024-01-26        10.71        -2.45    -0.02        10.98
# 79  BHIA3 2024-01-26         8.70        -2.46    -0.02         8.92
# 80  RENT3 2024-01-26        56.24        -3.63    -0.04        58.36
# 81  CVCB3 2024-01-26         3.07        -4.36    -0.04         3.21
# 82  GOLL4 2024-01-26         5.92        -8.07    -0.08         6.44
#
#     Qtde_teorica    Variacao_RS Resultado              Nome  \
# 0      515117391   241889725.43     Subiu          Usiminas
# 1     1110559345   177515970.30     Subiu     CSN Mineração
# 2     2379877655  2140059393.53     Subiu         Petrobras
# 3     2379877655  2140059393.53     Subiu         Petrobras
# 4      683452836   722946282.71     Subiu            Suzano
# ..           ...            ...       ...               ...
# 78     533990587  -143635530.57    Desceu  Carrefour Brasil
# 79      94843047   -20810240.84    Desceu       Casas Bahia
# 80     853202347 -1807432634.46    Desceu          Localiza
# 81     525582771   -73557408.06    Desceu               CVC
# 82     198184909  -102993202.62    Desceu               GOL
#
#              Segmento  Idade          Cat_Idade
# 0          Siderurgia     60  Entre de 50 e 100
# 1           Mineração     80  Entre de 50 e 100
# 2      Petróleo e Gás     69  Entre de 50 e 100
# 3      Petróleo e Gás     69  Entre de 50 e 100
# 4    Papel e Celulose     94  Entre de 50 e 100
# ..                ...    ...                ...
# 78             Varejo     66  Entre de 50 e 100
# 79             Varejo     68  Entre de 50 e 100
# 80  Aluguel de Carros     48        Menos de 50
# 81            Turismo     50  Entre de 50 e 100
# 82   Transporte Aéreo     20        Menos de 50
#
# [83 rows x 13 columns]

# %%
# Calcular a maior variação R$
maior_variacao_rs = df_principal['Variacao_RS'].max()

# Calcular a menor variação R$
menor_variacao_rs = df_principal['Variacao_RS'].min()

# Calcular a média
media_variacao_rs = df_principal['Variacao_RS'].mean()

# Calcular a média de quem subiu
media_subiu = df_principal[df_principal['Resultado'] == 'Subiu']['Variacao_RS'].mean()

# Calcular a média de quem desceu
media_desceu = df_principal[df_principal['Resultado'] == 'Desceu']['Variacao_RS'].mean()

# Exibir os resultados
print("Maior variação R$: {:.2f}".format(maior_variacao_rs))
print("Menor variação R$: {:.2f}".format(menor_variacao_rs))
print("Média R$: {:.2f}".format(media_variacao_rs))
print("Média de quem subiu R$: {:.2f}".format(media_subiu))
print("Média de quem Desceu R$: {:.2f}".format(media_desceu))
# Out:
# Maior variação R$: 4762926995.25
# Menor variação R$: -1807432634.46
# Média R$: 224380755.83
# Média de quem subiu R$: 542661362.93
# Média de quem Desceu R$: -181109141.75

# %%
df_principal_subiu = df_principal[df_principal['Resultado'] == 'Subiu']
df_principal_subiu
# Out:
#     Ativo       Data  Valor_Final  Var_Dia_PCT  Var_pct  Var_Inicial  \
# 0   USIM5 2024-01-26         9.50         5.20     0.05         9.03
# 1   CMIN3 2024-01-26         6.82         2.40     0.02         6.66
# 2   PETR3 2024-01-26        41.96         2.19     0.02        41.06
# 3   PETR3 2024-01-26        41.96         2.19     0.02        41.06
# 4   SUZB3 2024-01-26        52.91         2.04     0.02        51.85
# 5   CPFE3 2024-01-26        37.10         2.03     0.02        36.36
# 6   PRIO3 2024-01-26        45.69         1.98     0.02        44.80
# 7   PETR4 2024-01-26        39.96         1.73     0.02        39.28
# 8   PETR4 2024-01-26        39.96         1.73     0.02        39.28
# 9   VALE3 2024-01-26        69.50         1.66     0.02        68.37
# 10  MULT3 2024-01-26        28.19         1.58     0.02        27.75
# 11  ITUB4 2024-01-26        32.81         1.48     0.01        32.33
# 12  RDOR3 2024-01-26        27.56         1.43     0.01        27.17
# 13  BRKM5 2024-01-26        18.55         1.42     0.01        18.29
# 14  AZUL4 2024-01-26        14.27         1.42     0.01        14.07
# 15  RRRP3 2024-01-26        28.75         1.41     0.01        28.35
# 16  EQTL3 2024-01-26        35.32         1.34     0.01        34.85
# 17  CSNA3 2024-01-26        18.16         1.33     0.01        17.92
# 18  YDUQ3 2024-01-26        19.77         1.28     0.01        19.52
# 19  UGPA3 2024-01-26        28.31         1.28     0.01        27.95
# 20  MRVE3 2024-01-26         8.08         1.25     0.01         7.98
# 21  ARZZ3 2024-01-26        57.91         1.15     0.01        57.25
# 22  BBDC4 2024-01-26        15.52         1.04     0.01        15.36
# 23  BEEF3 2024-01-26         7.19         0.98     0.01         7.12
# 24  PCAR3 2024-01-26         4.14         0.97     0.01         4.10
# 25  BRFS3 2024-01-26        14.61         0.96     0.01        14.47
# 26  VIVT3 2024-01-26        51.20         0.88     0.01        50.75
# 27  RAIL3 2024-01-26        22.64         0.84     0.01        22.45
# 28  CIEL3 2024-01-26         4.90         0.82     0.01         4.86
# 29  DXCO3 2024-01-26         7.81         0.77     0.01         7.75
# 30  TIMS3 2024-01-26        17.52         0.74     0.01        17.39
# 31  BRAP4 2024-01-26        23.22         0.73     0.01        23.05
# 32  LWSA3 2024-01-26         5.55         0.72     0.01         5.51
# 33  RECV3 2024-01-26        23.83         0.71     0.01        23.66
# 34  ITSA4 2024-01-26        10.01         0.70     0.01         9.94
# 35  BBAS3 2024-01-26        56.97         0.68     0.01        56.59
# 36  RADL3 2024-01-26        26.16         0.61     0.01        26.00
# 37  GOAU4 2024-01-26        10.08         0.59     0.01        10.02
# 38  CSAN3 2024-01-26        18.57         0.59     0.01        18.46
# 39  JBSS3 2024-01-26        24.34         0.57     0.01        24.20
# 40  MGLU3 2024-01-26         2.08         0.48     0.00         2.07
# 41  BBDC3 2024-01-26        13.75         0.36     0.00        13.70
# 42  GGBR4 2024-01-26        21.84         0.27     0.00        21.78
# 43  RAIZ4 2024-01-26         3.74         0.26     0.00         3.73
# 44  CPLE6 2024-01-26        10.07         0.19     0.00        10.05
# 45  VAMO3 2024-01-26         8.18         0.12     0.00         8.17
#
#     Qtde_teorica   Variacao_RS Resultado                  Nome  \
# 0      515117391  241889725.43     Subiu              Usiminas
# 1     1110559345  177515970.30     Subiu         CSN Mineração
# 2     2379877655 2140059393.53     Subiu             Petrobras
# 3     2379877655 2140059393.53     Subiu             Petrobras
# 4      683452836  722946282.71     Subiu                Suzano
# 5      187732538  138573955.06     Subiu          CPFL Energia
# 6      800010734  709687498.18     Subiu              PetroRio
# 7     4566445852 3103136291.22     Subiu             Petrobras
# 8     4566445852 3103136291.22     Subiu             Petrobras
# 9     4196924316 4762926995.25     Subiu                  Vale
# 10     268505432  117732680.08     Subiu             Multiplan
# 11    4801593832 2297591984.33     Subiu         Itaú Unibanco
# 12    1168230366  453917907.01     Subiu             Rede D'Or
# 13     265877867   69054317.64     Subiu               Braskem
# 14     327593725   65452205.55     Subiu                  Azul
# 15     235665566   94204643.35     Subiu          3R Petroleum
# 16    1095587251  511671895.45     Subiu    Equatorial Energia
# 17     600865451  143220991.46     Subiu  Siderúrgica Nacional
# 18     289347914   72295838.99     Subiu                 YDUQS
# 19    1086411192  388705223.96     Subiu              Ultrapar
# 20     376187582   37525872.38     Subiu                   MRV
# 21      62305891   41021792.09     Subiu                Arezzo
# 22    5146576868  822148336.41     Subiu        Banco Bradesco
# 23     261036182   18214628.10     Subiu               Minerva
# 24     159430826    6340916.22     Subiu   Grupo Pão de Açúcar
# 25    1677525446  233045769.57     Subiu                   BRF
# 26     423091712  188965307.06     Subiu                  Vivo
# 27    1218352541  229771333.63     Subiu                  Rumo
# 28    1095462329   43657683.38     Subiu                 Cielo
# 29     302768240   18068446.61     Subiu                 Dexco
# 30     807896814  103972807.37     Subiu                   TIM
# 31     251003438   42238249.54     Subiu             Bradespar
# 32     393173139   15598886.65     Subiu               Locaweb
# 33     275005663   46201006.00     Subiu        PetroRecôncavo
# 34    5372783971  373853994.88     Subiu                Itaúsa
# 35    1420949112  546752087.99     Subiu       Banco do Brasil
# 36    1275798515  202352473.74     Subiu          RaiaDrogasil
# 37     660411219   39045606.94     Subiu    Metalúrgica Gerdau
# 38    1168097881  127229653.18     Subiu                 Cosan
# 39    1134986472  156573285.43     Subiu                   JBS
# 40    2867627068   28493619.27     Subiu        Magazine Luiza
# 41    1500728902   74019610.05     Subiu        Banco Bradesco
# 42    1118525506   65779607.10     Subiu                Gerdau
# 43    1193047233   11571106.42     Subiu                Raízen
# 44    1679335290   32069789.50     Subiu                 Copel
# 45     421383330    4131341.16     Subiu           Grupo Vamos
#
#                 Segmento  Idade          Cat_Idade
# 0             Siderurgia     60  Entre de 50 e 100
# 1              Mineração     80  Entre de 50 e 100
# 2         Petróleo e Gás     69  Entre de 50 e 100
# 3         Petróleo e Gás     69  Entre de 50 e 100
# 4       Papel e Celulose     94  Entre de 50 e 100
# 5                Energia    108   Mais de 100 anos
# 6         Petróleo e Gás     11        Menos de 50
# 7         Petróleo e Gás     69  Entre de 50 e 100
# 8         Petróleo e Gás     69  Entre de 50 e 100
# 9              Mineração     80  Entre de 50 e 100
# 10      Shopping Centers     50  Entre de 50 e 100
# 11  Serviços Financeiros     17        Menos de 50
# 12                 Saúde     12        Menos de 50
# 13               Química     52  Entre de 50 e 100
# 14      Transporte Aéreo     13        Menos de 50
# 15        Petróleo e Gás      8        Menos de 50
# 16               Energia     24        Menos de 50
# 17            Siderurgia     80  Entre de 50 e 100
# 18              Educação     20        Menos de 50
# 19               Energia     85  Entre de 50 e 100
# 20      Construção Civil     42        Menos de 50
# 21                  Moda     50  Entre de 50 e 100
# 22  Serviços Financeiros     77  Entre de 50 e 100
# 23             Alimentos     28        Menos de 50
# 24                Varejo     71  Entre de 50 e 100
# 25             Alimentos     85  Entre de 50 e 100
# 26      Telecomunicações     20        Menos de 50
# 27            Transporte      7        Menos de 50
# 28  Serviços Financeiros     11        Menos de 50
# 29              Comércio      4        Menos de 50
# 30      Telecomunicações     26        Menos de 50
# 31         Investimentos     20        Menos de 50
# 32            Tecnologia     23        Menos de 50
# 33        Petróleo e Gás     11        Menos de 50
# 34         Investimentos     53  Entre de 50 e 100
# 35  Serviços Financeiros     76  Entre de 50 e 100
# 36                 Saúde    122   Mais de 100 anos
# 37            Siderurgia    120   Mais de 100 anos
# 38               Energia     24        Menos de 50
# 39             Alimentos     68  Entre de 50 e 100
# 40                Varejo     63  Entre de 50 e 100
# 41  Serviços Financeiros     77  Entre de 50 e 100
# 42            Siderurgia    120   Mais de 100 anos
# 43               Energia      9        Menos de 50
# 44               Energia     66  Entre de 50 e 100
# 45            Transporte      7        Menos de 50

# %%
df_analise_segmento = df_principal_subiu.groupby('Cat_Idade')['Variacao_RS'].sum().reset_index()
df_analise_segmento['Variacao_RS'] = df_analise_segmento['Variacao_RS'].map('R${:,.2f}'.format)
df_analise_segmento
# Out:
#            Cat_Idade          Variacao_RS
# 0  Entre de 50 e 100  R$19,424,702,757.73
# 1   Mais de 100 anos     R$445,751,642.83
# 2        Menos de 50   R$5,091,968,294.32

# %%
df_analise_saldo = df_principal.groupby('Resultado')['Variacao_RS'].sum().reset_index()
df_analise_saldo['Variacao_RS'] = df_analise_saldo['Variacao_RS'].map('R${:,.2f}'.format)
df_analise_saldo
# Out:
#   Resultado          Variacao_RS
# 0    Desceu  R$-6,338,819,961.32
# 1   Estavel               R$0.00
# 2     Subiu  R$24,962,422,694.88

# %%
fig = px.bar(df_analise_saldo,x='Resultado',y='Variacao_RS',text='Variacao_RS',title="Variação real por reultado")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="cfa8eded-d1b7-4eaf-8b64-9ddec991836e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("cfa8eded-d1b7-4eaf-8b64-9ddec991836e")) {                    Plotly.newPlot(                        "cfa8eded-d1b7-4eaf-8b64-9ddec991836e",                        [{"alignmentgroup":"True","hovertemplate":"Resultado=%{x}\u003cbr\u003eVariacao_RS=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"text":["R$-6,338,819,961.32","R$0.00","R$24,962,422,694.88"],"textposition":"auto","x":["Desceu","Estavel","Subiu"],"xaxis":"x","y":["R$-6,338,819,961.32","R$0.00","R$24,962,422,694.88"],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity" ...

# %%
fig = px.pie(df_analise_segmento, values='Variacao_RS', names='Segmento', title='Gráfico de Pizza - Resultado da Variação por Segmento')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="36b862f5-362d-4387-98d9-9926f6d8c09b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("36b862f5-362d-4387-98d9-9926f6d8c09b")) {                    Plotly.newPlot(                        "36b862f5-362d-4387-98d9-9926f6d8c09b",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"Segmento=%{label}\u003cbr\u003eVariacao_RS=%{value}\u003cextra\u003e\u003c\u002fextra\u003e","labels":["Alimentos","Com\u00e9rcio","Constru\u00e7\u00e3o Civil","Educa\u00e7\u00e3o","Energia","Investimentos","Minera\u00e7\u00e3o","Moda","Papel e Celulose","Petr\u00f3leo e G\u00e1s","Qu\u00edmica","Sa\u00fade","Servi\u00e7os Financeiros","Shopping Centers","Siderurgia","Tecnologia","Telecomunica\u00e7\u00f5es","Transporte","Transporte A\u00e9reo","Varejo"],"legendgroup":"","name":"","showlegend":true,"values":[407833683.0924499,18068446.60998324,37525872.37728388,72295838.98616095,1209821623.5672965,416092244.423763,4940442965.550434,41021792.09077153,722946282.7090385,11336484517.004236,69054317.63603853,656270380.7530686,3784169702.158993,117732680.0784251,489935930.9283229,15598886.650556229,292938114.42357796,233902674.79257408,65452205.552800186,34834535.49753806],"type":"pie"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"o ...

# %%
df_analise_cat_idade = df_principal.groupby('Cat_Idade')['Variacao_RS'].sum().reset_index()
df_analise_cat_idade['Variacao_RS'] = df_analise_cat_idade['Variacao_RS'].map('R${:,.2f}'.format)
df_analise_cat_idade
# Out:
#            Cat_Idade          Variacao_RS
# 0  Entre de 50 e 100  R$17,469,591,325.61
# 1   Mais de 100 anos    R$-749,160,397.86
# 2        Menos de 50   R$1,903,171,805.82

# %%
fig = px.bar(df_analise_cat_idade, x='Cat_Idade', y='Variacao_RS', text='Variacao_RS', title='Variação Reais por Categoria de Idade')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="49bf63d7-40c3-4ef3-9255-617402880c41" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("49bf63d7-40c3-4ef3-9255-617402880c41")) {                    Plotly.newPlot(                        "49bf63d7-40c3-4ef3-9255-617402880c41",                        [{"alignmentgroup":"True","hovertemplate":"Cat_Idade=%{x}\u003cbr\u003eVariacao_RS=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"text":["R$17,469,591,325.61","R$-749,160,397.86","R$1,903,171,805.82"],"textposition":"auto","x":["Entre de 50 e 100","Mais de 100 anos","Menos de 50"],"xaxis":"x","y":["R$17,469,591,325.61","R$-749,160,397.86","R$1,903,171,805.82"],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"patte ...

# %%
df_soma_condicional = df_principal.groupby('Cat_Idade')['Idade'].count().reset_index()
df_soma_condicional
# Out:
#            Cat_Idade  Idade
# 0  Entre de 50 e 100     37
# 1   Mais de 100 anos      6
# 2        Menos de 50     40

# %%
fig = px.pie(df_soma_condicional, values='Idade', names='Cat_Idade', title='Gráfico de Pizza -Categoria de Idade por Empresas')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="ee01e6e8-4de3-4c39-a33e-1e403bdb1db6" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ee01e6e8-4de3-4c39-a33e-1e403bdb1db6")) {                    Plotly.newPlot(                        "ee01e6e8-4de3-4c39-a33e-1e403bdb1db6",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"Cat_Idade=%{label}\u003cbr\u003eIdade=%{value}\u003cextra\u003e\u003c\u002fextra\u003e","labels":["Entre de 50 e 100","Mais de 100 anos","Menos de 50"],"legendgroup":"","name":"","showlegend":true,"values":[37,6,40],"type":"pie"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"type":"scatterpolar","marker":{"colorbar":{"outlinewidth":0,"t ...
